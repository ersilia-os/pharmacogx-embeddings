# %%
import pandas as pd
import os

DATAPATH = "../data/pharmgkb_processed"

# %% [markdown]
# # Chemicals
#
# We are missing the SMILES for ~1.7k chemicals out of 4.5k. Many of them are from Drug Classes, and potentially could be separated into the different classes they are referred to.
# By searching with the PharmGKB API, we have only found 3 more SMILES. The PharmGKB API search is now incorporated in chemical.py for future uses.

# %%
#re-parse chemicals file to get smiles from API if they are not there and compare with original file

df = pd.read_csv(os.path.join(DATAPATH, "0_chemical.csv"))
print(len(df))
df = df[df["smiles"].isna()]
len(df)
# Out:
# 4532
# 1753

# %%
import requests

cid2smi = {}
for cid in df["cid"].tolist():
    url = "https://api.pharmgkb.org/v1/data/chemical/{}?view=base".format(cid)
    response = requests.get(url)

    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        print(data)
        try:
            smiles = data['data']['smiles']
            print("SMILES from API!")
            cid2smi[cid] = smiles
        except:
            smiles=None
    else:
        print("Failed to fetch data from the API. Status code:", response.status_code)
# Out:
# {'data': {'objCls': 'Chemical', 'id': 'PA166131395', 'name': '10-hydroxy r-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166165005', 'name': '12-hydroxy-sirolimus', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166160599', 'name': '14-hydroxyclarithromycin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131541', 'name': '1-hydroxyibuprofen glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131511', 'name': '2,3-diene valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131512', 'name': '2,4-diene valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712302', 'name': '2-amino-1-phenylethanol derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131572', 'name': '2-dechloroethyl ifosfamide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131568', 'name': 'dFdUMP', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131246', 'name': '2-ene valproic acid', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131250', 'name': '2-ene valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131468', 'name': '2-hydroxy-desethylamodiaquine', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131542', 'name': '2-hydroxyibuprofen glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166160755', 'name': '2-hydroxymethyl atomoxetine', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166165008', 'name': '34-hydroxy-sirolimus', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166165006', 'name': '39-o-desmethyl sirolimus', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131571', 'name': '3-dechloroethyl ifosfamide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131513', 'name': '3-ene valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131485', 'name': '3-hydroxycarbamazepine free radical', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131543', 'name': '3-hydroxyibuprofen glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131514', 'name': '3-hydroxy valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712303', 'name': '3-oxoandrosten (4) derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131515', 'name': '3-oxo-valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131245', 'name': '4-ene valproic acid', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131254', 'name': '4-ene valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131409', 'name': '4-hydroxytamoxifen-n-glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131408', 'name': '4-hydroxytamoxifen sulfate', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131516', 'name': '4-hydroxy valproic acid', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166159252', 'name': '4-hydroxyvoriconazole', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166159253', 'name': '4-hydroxyvoriconazole 4-o-glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA151958637', 'name': '4-methylthioamphetamine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA154081778', 'name': '4-methylumbelliferone', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712304', 'name': '5-androstanon (3) derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131488', 'name': "5'-glucuronyl zidovudine", 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166227981', 'name': '5-hydroxypimozide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131420', 'name': "5'-hydroxytegafur", 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179675', 'name': '5-hydroxytropisetron', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131517', 'name': '5-hydroxy valproic acid', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA151958362', 'name': '6,7-dihydroxybergamottin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166170822', 'name': '6-alpha-noroxycodol', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166170823', 'name': '6-beta-noroxycodol', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166228041', 'name': '6-hydroxypimozide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131394', 'name': '6-hydroxy r-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131393', 'name': '6-hydroxy s-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179676', 'name': '6-hydroxytropisetron', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166170918', 'name': '6-oxo-methylphenidate', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166170922', 'name': '6-oxo-ritalinic acid', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166226481', 'name': '7-carboxycannabidiol', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131554', 'name': '7-hydroxyefavirenz glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131397', 'name': '7-hydroxy r-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131399', 'name': '7-hydroxy s-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179677', 'name': '7-hydroxytropisetron', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131556', 'name': '8,14-dihydroxyefavirenz glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166160608', 'name': '8,9-anhydroerythronolide b 6,9-hemiketal', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA152530740', 'name': '8-cyclopentyl-1,3-dipropylxanthine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131555', 'name': '8-hydroxyefavirenz glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131396', 'name': '8-hydroxy r-warfarin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166160631', 'name': '8-hydroxythioguanine', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131239', 'name': '9,10-dihydrodeoxyartemisinin', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131545', 'name': 'abacavir minor metabolites', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164747080', 'name': 'abatacept', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448006', 'name': 'abciximab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166104276', 'name': 'ABT-751', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712305', 'name': 'ACE inhibitors and calcium channel blockers', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712306', 'name': 'ACE inhibitors and diuretics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712307', 'name': 'Ace Inhibitors, Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712308', 'name': 'Ace Inhibitors, Plain', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448014', 'name': 'acetamide mea', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166246281', 'name': 'acetaminophen / caffeine / dihydrocodeine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165290927', 'name': 'acetaminophen / propoxyphene napsylate', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166184496', 'name': 'acetaminophen / tramadol', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448016', 'name': 'acetanilide', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712309', 'name': 'Acetic acid derivatives and related substances', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448025', 'name': 'acetone', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712311', 'name': 'Acidifiers', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712310', 'name': 'Acid preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712312', 'name': 'Acridine derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712313', 'name': 'Acth', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712314', 'name': 'Actinomycines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166266341', 'name': 'acyclovir aldehyde', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10004', 'name': 'adalimumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712315', 'name': 'Adamantane derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712316', 'name': 'Adrenergic and dopaminergic agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712318', 'name': 'Adrenergics and other drugs for obstructive airway diseases', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712317', 'name': 'Adrenergics For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10405', 'name': 'adrenergics, inhalants', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452609', 'name': 'aflatoxin b1', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166118342', 'name': 'aflibercept', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166122586', 'name': 'afutuzumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712320', 'name': 'Agents Acting On The Renin-angiotensin System', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712321', 'name': 'Agents Against Amoebiasis And Other Protozoal Diseases', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712322', 'name': 'Agents Against Leishmaniasis And Trypanosomiasis', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712323', 'name': 'Agents For Treatment Of Hemorrhoids And', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712324', 'name': 'Aldehydes and derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448081', 'name': 'aldesleukin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712325', 'name': 'Aldose reductase inhibitors', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712326', 'name': 'Aldosterone antagonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166182583', 'name': 'alectinib metabolite M4', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164748040', 'name': 'alefacept', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164783958', 'name': 'alemtuzumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164748093', 'name': 'alglucerase', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164754753', 'name': 'alglucosidase alfa', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712327', 'name': 'Alimentary Tract And Metabolism', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166159961', 'name': 'alirocumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712328', 'name': 'Alkaloids, excl. rauwolfia', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712329', 'name': 'Alkaloids, excl. rauwolfia, in combination with diuretics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712331', 'name': 'Alkylating Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712330', 'name': 'Alkyl sulfonates', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712336', 'name': 'Allergen extracts', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712337', 'name': 'Allergens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA142320763', 'name': 'allopregnanolone', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712332', 'name': 'All Other Non-therapeutic Products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712334', 'name': 'All Other Therapeutic Products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA133888888', 'name': 'almokalant', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448322', 'name': 'aloe', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452626', 'name': 'alox5-pathway modifiers', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10308', 'name': 'alpha-1-proteinase inhibitor', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712344', 'name': 'Alpha-adrenoreceptor antagonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712346', 'name': 'Alpha-adrenoreceptor antagonists and diuretics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712343', 'name': 'Alpha- and beta-adrenoreceptor agonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712339', 'name': 'Alpha and beta blocking agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712340', 'name': 'Alpha and beta blocking agents and other diuretics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712341', 'name': 'Alpha and beta blocking agents and thiazides', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712342', 'name': 'Alpha glucosidase inhibitors', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166180537', 'name': 'alpha-hydroxy sertraline ketone glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131256', 'name': 'alpha-hydroxytamoxifen o-glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA147358765', 'name': 'alpha-methyl-para-tyrosine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164776730', 'name': 'alteplase', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712347', 'name': 'Aluminium agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712348', 'name': 'Aluminium compounds', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448348', 'name': 'aluminum chloride', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165958393', 'name': 'aluminum hydroxide', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166234821', 'name': 'aluminum hydroxide, magnesium hydroxide, drug combination', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165291491', 'name': 'alvespimycin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165860521', 'name': 'ambrisentan', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712349', 'name': 'Amides', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448372', 'name': 'amino acids', 'pediatric': False, 'types': ['Drug', 'Biological Intermediate']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712351', 'name': 'Amino acids and derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712353', 'name': 'Amino acids/carbohydrates/minerals/vitamins, combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712352', 'name': 'Amino acids, incl. combinations with polypeptides', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712354', 'name': 'Aminoalkyl ethers', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10247', 'name': 'aminobenzoic acid', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452167', 'name': 'aminoglycoside antibacterials', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712355', 'name': 'Aminoquinolines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712356', 'name': 'Aminosalicylic acid and derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712357', 'name': 'Aminosalicylic acid and similar agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166183785', 'name': 'amlodipine / atorvastatin / perindopril arginine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448392', 'name': 'ammonium chloride', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131469', 'name': 'amodiaquine M2', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712358', 'name': 'Amphenicols', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712360', 'name': 'Anabolic Agents For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712361', 'name': 'Anabolic Steroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165960688', 'name': 'anacetrapib', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10799', 'name': 'anakinra', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712362', 'name': 'Analgesics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712363', 'name': 'Analgesics and anesthetics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712364', 'name': 'Androgen, progestogen and estrogen in combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10381', 'name': 'androgens and estrogens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712365', 'name': 'Androgens And Female Sex Hormones In Combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712366', 'name': 'Androgens and female sex hormones in combination with other drugs', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10733', 'name': 'androgens for topical use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712367', 'name': 'Androstan derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712372', 'name': 'Angiotensin II Antagonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712368', 'name': 'Angiotensin II antagonists and calcium channel blockers', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712369', 'name': 'Angiotensin II antagonists and diuretics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712371', 'name': 'Angiotensin II Antagonists, Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166277641', 'name': 'anifrolumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712373', 'name': 'Anilides', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164769075', 'name': 'anistreplase', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452298', 'name': 'antacids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712377', 'name': 'Antacids, other combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712374', 'name': 'Antacids with antiflatulents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712375', 'name': 'Antacids with antispasmodics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712376', 'name': 'Antacids with sodium bicarbonate', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712378', 'name': 'Anterior Pituitary Lobe Hormones And Analogues', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712379', 'name': 'Anthelmintics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA130620651', 'name': 'anthracyclines and related substances', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712380', 'name': 'Anthrax vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712381', 'name': 'Anti-acne Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712382', 'name': 'Anti-acne Preparations For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712383', 'name': 'Anti-acne Preparations For Topical Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712390', 'name': 'Antiadrenal Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712391', 'name': 'Antiadrenergic Agents, Centrally Acting', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712392', 'name': 'Antiadrenergic Agents, Ganglion-blocking', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712393', 'name': 'Antiadrenergic Agents, Peripherally Acting', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712394', 'name': 'Antiallergic agents, excl. corticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712397', 'name': 'Antiandrogens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712384', 'name': 'Anti-androgens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712398', 'name': 'Antiandrogens and estrogens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712399', 'name': 'Antiandrogens, plain', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712400', 'name': 'Antianemic Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712402', 'name': 'Antiarrhythmics, class Ia', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452249', 'name': 'antiarrhythmics, class i and iii', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712403', 'name': 'Antiarrhythmics, class Ib', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712404', 'name': 'Antiarrhythmics, class Ic', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712401', 'name': 'Antiarrhythmics, class III', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712405', 'name': 'Antibacterials For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712406', 'name': 'Antibiotics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712415', 'name': 'Antibiotics And Chemotherapeutics, Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712414', 'name': 'Antibiotics And Chemotherapeutics For Dermatological Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712417', 'name': 'Antibiotics and corticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712416', 'name': 'Antibiotics For Topical Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712418', 'name': 'Anticestodals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712419', 'name': 'Anticholinergic Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712420', 'name': 'Anticholinergics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712423', 'name': 'Anticholinesterases', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712424', 'name': 'Anticorticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712385', 'name': 'Anti-dementia Drugs', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452229', 'name': 'antidepressants', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712425', 'name': 'Antidepressants in combination with psycholeptics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712426', 'name': 'Antidiarrheal Microorganisms', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712428', 'name': 'Antidiarrheals, Intestinal Antiinflammatory/antiinfective', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712429', 'name': 'Antidotes', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712431', 'name': 'Antiemetics And Antinauseants', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA143485705', 'name': 'antiepileptics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712386', 'name': 'Anti-estrogens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712433', 'name': 'Antifibrinolytics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712434', 'name': 'Antifungals For Dermatological Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712435', 'name': 'Antifungals For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712436', 'name': 'Antifungals For Topical Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10393', 'name': 'antiglaucoma preparations and miotics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712387', 'name': 'Anti-gonadotropin-releasing hormones', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712438', 'name': 'Antigonadotropins and similar agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712440', 'name': 'Antigout Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712441', 'name': 'Antigrowth hormones', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164750168', 'name': 'antihemophilic factor', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712442', 'name': 'Antihemorrhagics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712443', 'name': 'Antihidrotics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712444', 'name': 'Antihistamines For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712445', 'name': 'Antihypertensives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712446', 'name': 'Antihypertensives And Diuretics In Combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712447', 'name': 'Antiinfectives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712453', 'name': 'Antiinfectives And Antiseptics, Excl. Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712455', 'name': 'Antiinfectives and antiseptics for local oral treatment', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712457', 'name': 'Antiinfectives/antiseptics In Combination With Corticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712454', 'name': 'Antiinfectives For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712456', 'name': 'Antiinfectives for treatment of acne', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712458', 'name': 'Antiinflammatory Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712460', 'name': 'Antiinflammatory Agents And Antiinfectives In Combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712462', 'name': 'Antiinflammatory agents, non-steroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712463', 'name': 'Antiinflammatory agents, non-steroids and antiinfectives in combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712461', 'name': 'Antiinflammatory And Antirheumatic Products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10384', 'name': 'antiinflammatory and antirheumatic products, non-steroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712466', 'name': 'Antiinflammatory/antirheumatic Agents In Combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712467', 'name': 'Antiinflammatory/antirheumatic agents in combination with corticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712464', 'name': 'Antiinflammatory preparations, non-steroids for topical use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712465', 'name': 'Antiinflammatory products for vaginal administration', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712468', 'name': 'Antimalarials', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452622', 'name': 'antimetabolites', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712469', 'name': 'Antimigraine Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712470', 'name': 'Antimony compounds', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA448452', 'name': 'antimony potassium tartrate', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712471', 'name': 'Antimycobacterials', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712473', 'name': 'Antimycotics For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712474', 'name': 'Antinematodal Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452621', 'name': 'antineoplastic agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712475', 'name': 'Antineoplastic And Immunomodulating Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712476', 'name': 'Antineovascularisation agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712478', 'name': 'Antiobesity Preparations, Excl. Diet Products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712479', 'name': 'Antiparasitic Products, Insecticides And Repellents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712388', 'name': 'Anti-parathyroid Agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712389', 'name': 'Anti-parkinson Drugs', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712480', 'name': 'Antiprogestogens', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712482', 'name': 'Antipropulsives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712483', 'name': 'Antiprotozoals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712484', 'name': 'Antipruritics, Incl. Antihistamines, Anesthetics, Etc.', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712486', 'name': 'Antipsoriatics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712487', 'name': 'Antipsoriatics For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712488', 'name': 'Antipsoriatics For Topical Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452233', 'name': 'antipsychotics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712489', 'name': 'Antiseptics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712492', 'name': 'Antiseptics and corticosteroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712491', 'name': 'Antiseptics And Disinfectants', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712493', 'name': 'Antispasmodics And Anticholinergics In Combination With Other Drugs', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712494', 'name': 'Antispasmodics In Combination With Analgesics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712496', 'name': 'Antispasmodics in combination with other drugs', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712495', 'name': 'Antispasmodics In Combination With Psycholeptics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712497', 'name': 'Antispasmodics, psycholeptics and analgesics in combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452200', 'name': 'antithrombotic agents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164743704', 'name': 'antithymocyte globulin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712499', 'name': 'Antithyroid Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712500', 'name': 'Antitrematodals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712501', 'name': 'Antivaricose Therapy', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712502', 'name': 'Antivertigo Preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452174', 'name': 'antivirals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712504', 'name': 'Antivirals For Systemic Use', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712505', 'name': 'Antivirals for treatment of HIV infections, combinations', 'pediatric': True, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712506', 'name': 'Antracen derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712507', 'name': 'Anxiolytics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166209601', 'name': 'APL-9', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712508', 'name': 'Appetite Stimulants', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166183406', 'name': 'apple juice', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166162383', 'name': 'AR-C124910XX', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164746540', 'name': 'arcitumomab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712509', 'name': 'Arsenic compounds', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452638', 'name': 'arsenite', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA143485261', 'name': 'artemisinin and derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131467', 'name': 'artemisinin crystal-7', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712512', 'name': 'Arteriolar Smooth Muscle, Agents Acting On', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166182783', 'name': 'articaine / epinephrine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451998', 'name': 'arylhydrazines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712513', 'name': 'Aryloxyacetic acid derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712515', 'name': 'Ascorbic acid (vitamin C), combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164712514', 'name': 'Ascorbic Acid (vitamin C), Incl. Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# ...
# {'data': {'objCls': 'Chemical', 'id': 'PA164713361', 'name': 'Triazole derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451755', 'name': 'trichloroacetic acid', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA151929741', 'name': 'trichostatin A', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165958661', 'name': 'triciribine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165958430', 'name': 'triflusal', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451776', 'name': 'triglycerides', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713363', 'name': 'Trimethoprim and derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451802', 'name': 'trometamol', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179678', 'name': 'tropisetron 5-sulfate', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179673', 'name': 'tropisetron 6-glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179679', 'name': 'tropisetron 6-sulfate', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179674', 'name': 'tropisetron 7-glucuronide', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166179680', 'name': 'tropisetron 7-sulfate', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451806', 'name': 'trypsin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713364', 'name': 'Tuberculosis diagnostics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713365', 'name': 'Tuberculosis vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713366', 'name': 'Tumor necrosis factor alpha (TNF-alpha) inhibitors', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713367', 'name': 'Tumour Detection', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713368', 'name': 'Typhoid vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713369', 'name': 'Typhus (exanthematicus) vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713370', 'name': 'Tyrosine hydroxylase inhibitors', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713371', 'name': 'Ultrasound Contrast Media', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166184235', 'name': 'umeclidinium / vilanterol', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713373', 'name': 'Unclassified', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713374', 'name': 'Urinary antispasmodics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713375', 'name': 'Urinary concrement solvents', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713376', 'name': 'Urine Tests', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713377', 'name': 'Urologicals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166048654', 'name': 'ustekinumab', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166205401', 'name': 'efmarodocokin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713378', 'name': 'Vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA151917011', 'name': 'valinomycin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131510', 'name': 'valproic acid-coenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131521', 'name': 'valproic acid-dephosphocoenzyme A', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164924565', 'name': 'Valspodar', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451852', 'name': 'vanillin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713379', 'name': 'Varicella zoster vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713380', 'name': 'Various', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713381', 'name': 'Various alimentary tract and metabolism products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713382', 'name': 'Various diagnostic radiopharmaceuticals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713383', 'name': 'Various pain palliation radiopharmaceuticals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713384', 'name': 'Various therapeutic radiopharmaceuticals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713385', 'name': 'Various thyroid diagnostic radiopharmaceuticals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713386', 'name': 'Vasodilators Used In Cardiac Diseases', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713387', 'name': 'Vasopressin and analogues', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713388', 'name': 'Vasopressin antagonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713389', 'name': 'Vasoprotectives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451862', 'name': 'vegetable oil', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166115366', 'name': 'velaglucerase alfa', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA165290925', 'name': 'Vicodin', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166236421', 'name': 'viltolarsen', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA150481188', 'name': 'vinca alkaloids and analogues', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131423', 'name': 'vincristine M2', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131424', 'name': 'vincristine M4', 'pediatric': False, 'types': ['Metabolite']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452612', 'name': 'vinyl chloride', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713390', 'name': 'Viral Vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713391', 'name': 'Viscoelastic substances', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713392', 'name': 'Vitamin A And D, Incl. Combinations Of The Two', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713393', 'name': 'Vitamin A and D in combination', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713394', 'name': 'Vitamin A, plain', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA449069', 'name': 'vitamin b12 and folic acid', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713403', 'name': 'Vitamin B12 (cyanocobalamin and analogues)', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713400', 'name': 'Vitamin B1 in combination with vitamin B6 and/or vitamin B12', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713402', 'name': 'Vitamin B1, plain', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713401', 'name': 'Vitamin B1, Plain And In Combination With Vitamin B6 And B12', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713398', 'name': 'Vitamin B-complex, Incl. Combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713399', 'name': 'Vitamin B-complex, other combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA10505', 'name': 'vitamin b-complex, plain', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713395', 'name': 'Vitamin B-complex with anabolic steroids', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713396', 'name': 'Vitamin B-complex with minerals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713397', 'name': 'Vitamin B-complex with vitamin C', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451899', 'name': 'vitamin d and analogues', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713404', 'name': 'Vitamin K and analogues', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713405', 'name': 'Vitamin K And Other Hemostatics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713406', 'name': 'Vitamin K antagonists', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713407', 'name': 'Vitamins', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713410', 'name': 'Vitamins, other combinations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713409', 'name': 'Vitamins with minerals', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166131630', 'name': 'volatile anesthetics', 'pediatric': True, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166277621', 'name': 'vutrisiran', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713411', 'name': 'Wart and anti-corn preparations', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713412', 'name': 'Washing agents etc.', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713413', 'name': 'Watersoluble, hepatotropic X-ray contrast media', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713414', 'name': 'Watersoluble, nephrotropic, high osmolar X-ray contrast media', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713415', 'name': 'Watersoluble, nephrotropic, low osmolar X-ray contrast media', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA152432579', 'name': 'xanomeline', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713418', 'name': 'Xanthine derivatives', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713420', 'name': 'Xanthines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713421', 'name': 'Xanthines and adrenergics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452604', 'name': 'xenobiotics', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451935', 'name': 'xenon', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164924566', 'name': 'XR9051', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713416', 'name': 'X-ray Contrast Media, Iodinated', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713417', 'name': 'X-ray Contrast Media, Non-iodinated', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713422', 'name': 'Yellow fever vaccines', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713423', 'name': 'Yttrium (90Y) compounds', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA166184503', 'name': 'zidovudine / lamivudine / abacavir', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451961', 'name': 'zinc acetate', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713425', 'name': 'Zinc bandages', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451965', 'name': 'zinc oxide', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164713426', 'name': 'Zinc products', 'pediatric': False, 'types': ['Drug Class']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA451971', 'name': 'zinc sulfate', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA164924567', 'name': 'Zosuquidar', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}
# {'data': {'objCls': 'Chemical', 'id': 'PA452606', 'name': 'zoxazolamine', 'pediatric': False, 'types': ['Drug']}, 'status': 'success'}

# %%
cid2smi #we have manually modified these three to avoid the re-fetching of all smiles
# Out:
# {'PA164748138': 'C[C@H](CCCC(C)C)[C@H]1CC[C@@H]2[C@@]1(CCCC2=CC=C3C[C@H](CCC3=C)O)C',
#  'PA449932': 'CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2CCC4=CC(=O)CC[C@]34C)C)O',
#  'PA451652': 'CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCO'}

# %% [markdown]
# # Genes, haplotypes and variants
#
# We have 24.5k genes, but only 1k have information about variants/haplotypes. We are assuming that if a gene does not have any described haplotype or variant, it will not have any PGx annotation in PharmGKB.
# The genes do not have their variants listed when searching via the API, that is why we have parsed the rlx file as the source of truth for haplotypes, and from there we are getting the variants.

# %%
gene = pd.read_csv(os.path.join(DATAPATH,"0_gene.csv"))
rlx = pd.read_csv(os.path.join(DATAPATH,"1_haplotype_rlx.csv"))
haps = pd.read_csv(os.path.join(DATAPATH, "2_haplotype.csv"))

print("All genes in Pharmgkb: ", len(gene))
print("All genes with haplotypes/variants in PharmGKB: ", len(set(rlx["gid"])))
# Out:
# All genes in Pharmgkb:  24550
# All genes with haplotypes/variants in PharmGKB:  45
# All haplotypes in PharmGKB:

# %%
#Manually check that indeed genes that are not in the RLX file do not have variants reported in PharmGKB
no_hap = gene[~gene['gid'].isin(rlx['gid'])]
print(len(no_hap))
print("Genes without haplotypes: ", no_hap.sample(n=10)['gid'].tolist())
print("Genes with haplotypes: ", rlx.sample(n=10)['gid'].tolist())
# Out:
# 24505
# Genes without haplotypes:  ['PA134880462', 'PA36352', 'PA26680', 'PA28694', 'PA25001', 'PA134861867', 'PA134958992', 'PA31958', 'PA30602', 'PA134957759']
# Genes with haplotypes:  ['PA28469', 'PA28469', 'PA124', 'PA124', 'PA356', 'PA128', 'PA121', 'PA28469', 'PA124', 'PA126']

# %% [markdown]
# # Haplotype to variant
#
# We get the information of the variants found within an haplotype by downloading all haplotype files from PharmGKB (by gene)

# %%
#genes for which there is haplotype information:
assert len(list(set(gene["gene"].tolist()))) == len(no_hap)+len(list(set(rlx["gene"].tolist())))
print("Genes with Haplotypes: ", len(list(set(rlx["gene"].tolist()))))
# Out:
# Genes with Haplotypes:  45

# %%
folder_path = os.path.join(DATAPATH, "haplotypes")
files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
num_files = len(files)
print(f"There are {num_files} files in the haplotype folder.")
gene_names = [f.split('_')[0] for f in files]
# Out:
# There are 49 files in the haplotype folder.

# %%
gene_names_rlx = list(set(rlx["gene"].tolist()))

# %%
new_genes = set(gene_names) - set(gene_names_rlx)
print(new_genes)
print(len(list(new_genes))-1, " genes were not in RLX but have a Haplotype file in PharmGKB")
# Out:
# {'VKORC1', 'manual', 'ABCG2', 'F5'}
# 3  genes were not in RLX but have a Haplotype file in PharmGKB

# %%
new_genes = set(gene_names_rlx) - set(gene_names)
print(new_genes)
print(len(list(new_genes)), " genes were in RLX but do not have a Haplotype file in PharmGKB")
# Out:
# set()
# 0  genes were in RLX but do not have a Haplotype file in PharmGKB

# %%
#also quickly check we are not missing any gene from rlx
import sys 
cwd = os.getcwd()
sys.path.append(os.path.join(cwd, "..", "src"))
from pharmgkb import RawData
def get_raw_files():
    r = RawData()
    df = r.relationships
    return df

df = get_raw_files()

entity_types = list(set(df["Entity1_type"].tolist()))
print(entity_types)
# Out:
# ['Chemical', 'Variant', 'Haplotype', 'Disease', 'Gene']

# %%
df1 = df[df["Entity1_type"] == "Haplotype"]
print(df1.shape)
df1.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)
print(df1.shape)
# Out:
# (11788, 11)
# (1028, 11)
# /tmp/ipykernel_19162/2548395609.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)

# %%
df2 = df[df["Entity2_type"] == "Haplotype"]
print(df2.shape)
df2.drop_duplicates(subset=["Entity2_name"], keep="first", inplace=True)
print(df2.shape)
# Out:
# (11788, 11)
# (1029, 11)
# /tmp/ipykernel_19162/1164351352.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop_duplicates(subset=["Entity2_name"], keep="first", inplace=True)

# %%
h2v = pd.read_csv(os.path.join(DATAPATH, "3_hid_vid_complete.csv"))
print(h2v. shape)
print(len(set(h2v["vid"])), " unique variants associated to an haplotype") 

#why the difference?
h2v_nohla = h2v[~h2v["haplotype"].str.contains('HLA')]
print(h2v_nohla.shape)
# Out:
# (8715, 12)
# 1111  unique variants associated to an haplotype
# (3549, 12)

# %% [markdown]
# ### Variants

# %%
vars = pd.read_csv(os.path.join(DATAPATH, "5_variant_complete.csv"))
vars.shape
# Out:
# (7771, 4)

# %%
df1 = df[df["Entity1_type"] == "Variant"]
print(df1.shape)
df1.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)
print(df1.shape)

df2 = df[df["Entity1_type"] == "Variant"]
print(df2.shape)
df2.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)
print(df2.shape)
# Out:
# (28032, 11)
# (6307, 11)
# (28032, 11)
# (6307, 11)
# /tmp/ipykernel_19162/3344642574.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)
# /tmp/ipykernel_19162/3344642574.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop_duplicates(subset=["Entity1_name"], keep="first", inplace=True)

# %%
vars_rlx = list(set(df1["Entity1_id"]))
print(len(vars_rlx), " Unique Variants in Relationship file")
print(len(set(vars["vid"])), "Unique Variants in Variants file")
# Out:
# 6307  Unique Variants in Relationship file
# 6777 Unique Variants in Variants file

# %%
vars_h2v = list(set(h2v["vid"]))
vars_rlx = list(set(df1["Entity1_id"]))
vars_file = list(set(vars["vid"]))

print(len(vars_h2v), " Unique Variants in Hid to Vid file")
print(len(vars_rlx), " Unique Variants in Relationship file")
print(len(set(vars["vid"])), "Unique Variants in Variants file")

print(len(set(vars_h2v)-set(vars_file)), " Variants present in Hid2Vid but not in Variant File")
print(len(set(vars_rlx)-set(vars_file)), " Variants present in RLX file but not in Variant File")
print(len(set(vars_h2v)-set(vars_rlx)), " Variants present in H2V but not RLX")
# Out:
# 1111  Unique Variants in Hid to Vid file
# 6307  Unique Variants in Relationship file
# 6777 Unique Variants in Variants file
# 548  Variants present in Hid2Vid but not in Variant File
# 63  Variants present in RLX file but not in Variant File
# 766  Variants present in H2V but not RLX

# %%
# Total Unique Variants

total_vars = set(vars_h2v+vars_rlx+vars_file)
print(len(total_vars))
# Out:
# 7388
