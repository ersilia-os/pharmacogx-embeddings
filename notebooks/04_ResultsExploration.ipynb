# %%
import pandas as pd

df = pd.read_csv("../results/chemical_gene_pairs_prediction_output.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df_ = df[df["chemical"] == "ethionamide"]
df_ = df_[df_["train_set"] == 0]
df_ = df_[df_["adme_gene"] == 1]

# %%
df_.sort_values(by="y_hat_only_pk_only_adme_genes", ascending=False)
# Out:
#                           inchikey          cid     chemical uniprot_ac  \
# 31661  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     Q02325
# 31630  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     Q8N1D0
# 31647  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     Q6V0L0
# 30167  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     Q7LGC8
# 29842  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     P21439
# ...                            ...          ...          ...        ...
# 30445  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     O00337
# 30487  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     O15440
# 30032  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     P04798
# 30164  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     P33527
# 30785  AEOCXXJPGCBFJA-UHFFFAOYSA-N  PA164768738  ethionamide     P24462
#
#              gene                                       gid  chemical_in_pgkb  \
# ...
