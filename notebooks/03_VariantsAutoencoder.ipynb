# %% [markdown]
# # Variant embeddings
#
# In this notebook, we explore strategies to obtain simple vector embeddings from the variant annotation tabular data.
#
# These articles are interesting:
# - https://direct.mit.edu/tacl/article/doi/10.1162/tacl_a_00544/115239/Transformers-for-Tabular-Data-Representation-A
#
# ```python
# with open("codebook.tsv", "w") as f:
#     writer = csv.writer(f, delimiter="\t")
#     writer.writerow(["index", "column_name"])
#     for i, c in enumerate(list(df.columns)):
#         writer.writerow([i, c])
# ``````

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("../data/variants/1000_Genomes/10000_subset_snvs_coding_1kGPhg38.tsv", sep="\t")

# %%
columns = list(df.columns)

population_frequencies_columns = columns[slice(columns.index("AF"), columns.index("dbNSFP_ExAC_SAS_AF")+1)]
dfreq = pd.DataFrame(df[population_frequencies_columns])

# %%
prediction_scores_columns = columns[slice(columns.index("dbNSFP_CADD_phred"), columns.index("dbNSFP_VEST4_score")+1)]

df["dbNSFP_Polyphen2_HDIV_pred"].replace({'B': 0, 'P': 1, 'D': 2}, inplace=True)
df["dbNSFP_SIFT_pred"].replace({'D': 1, 'T': 0}, inplace=True)
df["dbNSFP_MutationAssessor_pred"].replace({'H': 3, 'M': 2, "L": 1, "N": 0}, inplace=True)
df["dbNSFP_MutationTaster_pred"].replace({"A": 2, "D": 1, "N": 0, "P": 0}, inplace=True)
def calculate_value(s):
    values = s.split(',')
    values = [v for v in values if v != '.']
    if not values:
        return float('NaN')
    mean_value = sum([1 if v == 'D' else 0 for v in values]) / len(values)
    return mean_value
df['dbNSFP_PROVEAN_pred'] = df['dbNSFP_PROVEAN_pred'].apply(calculate_value)
dpred = pd.DataFrame(df[prediction_scores_columns])
dpred.replace(".", np.nan, inplace=True)

# %%
other_columns = columns[slice(columns.index("dbNSFP_clinvar_id"), columns.index("dbNSFP_Interpro_domain")+1)]
texts = []
for v in df[["dbNSFP_clinvar_clnsig", "dbNSFP_clinvar_trait", "COSV_ID"]].values:
    t = ""
    if v[0] != ".":
        t += "The clinical relevance of the variant is {0}. ".format(v[0])
    else:
        t += "The clinical relevance of the variant is not annotated. "
    if v[1] != ".":
        t += "The traits are {0}. ".format(v[1].replace("_", " "))
    else:
        t += "No traits are known. "
    if v[2] != ".":
        t += "The affected domains of the variant in COSMIC are {0}.".format(v[2])
    else:
        t += "No domains in COSMIC."
    texts += [t]

# %%
texts
# Out:
# ['The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Three M syndrome 2 not specified not provided. The affected domains of the variant in COSMIC are Immunoglobulin-like_domain_Immunoglobulin_subtype_2_Immunoglobulin_subtype.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Vps16__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Peptidase_family_A1_domain_Peptidase_family_A1_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Cadherin-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Histidyl_tRNA_synthetase-related_domain.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are Seizures Neuronal ceroid lipofuscinosis 10 Neuronal ceroid lipofuscinosis not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Tetratricopeptide_repeat-containing_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are DDE_superfamily_endonuclease_domain.',
#  'The clinical relevance of the variant is Benign. The traits are Methylmalonyl-CoA epimerase deficiency not specified. The affected domains of the variant in COSMIC are Vicinal_oxygen_chelate__VOC__domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Domain_of_unknown_function_DUF4650.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Carbohydrate-binding_WSC_Carbohydrate-binding_WSC_Carbohydrate-binding_WSC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not specified. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are RGS_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are ADAM__cysteine-rich_ADAM__cysteine-rich.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Aminotransferase__class_I/classII.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Mitochondrial DNA-depletion syndrome 3, hepatocerebral not provided. The affected domains of the variant in COSMIC are Deoxynucleoside_kinase_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Hereditary breast and ovarian cancer syndrome not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are RGS_domain_RGS_domain_RGS_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sugar_isomerase__SIS__Sugar_isomerase__SIS__GlmS/AgaS.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Retinitis pigmentosa not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. The affected domains of the variant in COSMIC are GPCR_family_3.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Aminotransferase_class_V_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Ataxin__AXH_domain_Ataxin__AXH_domain_Ataxin__AXH_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Immunoglobulin-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Kinesin_motor_domain_Kinesin_motor_domain_Kinesin_motor_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Brugada syndrome not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Netrin_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Ribosomal_protein_S4/S9__N-terminal_Ribosomal_protein_S4/S9__N-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are EVA1_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Hereditary breast and ovarian cancer syndrome Breast-ovarian cancer, familial 1 Hereditary cancer-predisposing syndrome not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Likely_benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are APOBEC-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are WD40-repeat-containing_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger__CCCH-type_Zinc_finger__CCCH-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Roadblock/LAMTOR2_domain_Roadblock/LAMTOR2_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Intermediate_filament__rod_domain_Intermediate_filament__rod_domain_Intermediate_filament__rod_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Hemopexin-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Domain_of_unknown_function_DUF4195.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sec23/Sec24.',
#  'The clinical relevance of the variant is Likely_benign. The traits are Emery-Dreifuss muscular dystrophy 5, autosomal dominant. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Glycosyltransferase_2-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are EF-hand_domain_EF-hand_domain_EF-hand_domain_EF-hand_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are VHS_domain_VHS_domain_VHS_domain.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are LAMA2-related muscular dystrophy not specified. The affected domains of the variant in COSMIC are Laminin_alpha__domain_I.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Trypsin_Inhibitor-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sema_domain_Sema_domain_Sema_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Likely_benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are NUC194_NUC194.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Qualitative or quantitative defects of dysferlin. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Pendred syndrome Deafness, autosomal recessive 4, with enlarged vestibular aqueduct Primary autosomal recessive microcephaly 5 not specified not provided. The affected domains of the variant in COSMIC are SLC26A/SulP_transporter_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are DDHD_domain_DDHD_domain_DDHD_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Glutathione_S-transferase__C-terminal_Glutathione_S-transferase__C-terminal-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Fungal_lipase-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are THAP-type_zinc_finger_THAP-type_zinc_finger.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Marvel_domain_Marvel_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Olfactomedin-like_domain_Olfactomedin-like_domain_Olfactomedin-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Krueppel-associated_box_Krueppel-associated_box_Krueppel-associated_box_Krueppel-associated_box.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Mediator_complex__subunit_Med25__PTOV_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Major_facilitator_superfamily_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Rhodanese-like_domain_Rhodanese-like_domain_Rhodanese-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are PTP_type_protein_phosphatase_PTP_type_protein_phosphatase_PTP_type_protein_phosphatase.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR__rhodopsin-like__7TM.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sulfotransferase_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Hereditary insensitivity to pain with anhidrosis. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Membrane_attack_complex_component/perforin__MACPF__domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Lon__substrate-binding_domain_Lon__substrate-binding_domain_Lon__substrate-binding_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Neuropathy, hereditary sensory and autonomic, type VII Episodic pain syndrome, familial, 3. The affected domains of the variant in COSMIC are Ion_transport_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Rad50/SbcC-type_AAA_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Cadherin-like_Cadherin-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are A-kinase_anchor_110kDa__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Acrocallosal syndrome not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not provided. The affected domains of the variant in COSMIC are Peptidase_C2__calpain__large_subunit__domain_III_Peptidase_C2__calpain__domain_III_Calpain_subdomain_III.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Likely_benign. The traits are Sjögren-Larsson syndrome not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Deafness, autosomal recessive 36, with or without vestibular involvement. No domains in COSMIC.',
#  'The clinical relevance of the variant is Likely_benign. The traits are Epileptic encephalopathy. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Insulin-like_growth_factor-binding_protein.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. The affected domains of the variant in COSMIC are Lipocalin/cytosolic_fatty-acid_binding_domain_Cytosolic_fatty-acid_binding.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Immunoglobulin-like_domain_Immunoglobulin_subtype_2_Immunoglobulin_subtype.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Ion_transport_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Intermediate_filament__rod_domain_Intermediate_filament__rod_domain_Intermediate_filament__rod_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are PDZ_domain_PDZ_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR_family_3__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Ullrich congenital muscular dystrophy 1 Bethlem myopathy 1 not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Keratin_type_II_head.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Renal cell carcinoma Renal cell carcinoma, papillary, 1 Hereditary cancer-predisposing syndrome not provided. The affected domains of the variant in COSMIC are Sema_domain_Sema_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are Serum amyloid a variant not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Cutis laxa, autosomal recessive IIIA Hereditary spastic paraplegia 9A Cutis laxa, autosomal dominant 3. The affected domains of the variant in COSMIC are Aspartate/glutamate/uridylate_kinase.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are G_protein-regulated_inducer_of_neurite_outgrowth__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sulfotransferase_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sox_7/17/18__central_domain.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are Luscan-lumish syndrome not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. The affected domains of the variant in COSMIC are TSG101_and_ALIX_binding_domain_of_CEP55.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR__rhodopsin-like__7TM.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are Peroxisome biogenesis disorder Zellweger spectrum disorders. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Hereditary cancer-predisposing syndrome Hereditary nonpolyposis colorectal neoplasms not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Cadherin__C-terminal_catenin-binding_domain.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Ehlers-Danlos syndrome, classic type not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Protein_kinase_domain_Protein_kinase_domain.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. The affected domains of the variant in COSMIC are Protein_kinase_domain_Protein_kinase_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Nephronophthisis Nephronophthisis 4 Senior-Loken syndrome 4 not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Helicase__C-terminal_Helicase__C-terminal_Helicase__C-terminal_Helicase__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Cadherin-like_Cadherin-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are EVE_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Peptidase_M24.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Spinocerebellar ataxia, autosomal recessive 8 Emery-Dreifuss muscular dystrophy 4, autosomal dominant not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are Renal hypomagnesemia 2 not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are Porencephaly 2 Hemorrhage, intracerebral, susceptibility to not provided. The affected domains of the variant in COSMIC are Collagen_IV.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Ankyrin_repeat-containing_domain_Ankyrin_repeat-containing_domain_Ankyrin_repeat-containing_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Plexin__cytoplasmic_RasGAP_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are SH2_domain_SH2_domain_SH2_domain_SH2_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Transglutaminase-like_Transglutaminase-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Aldehyde_dehydrogenase_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type_Zinc_finger_C2H2-type.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are CSPG5__sulphate_attachment_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are NACHT_nucleoside_triphosphatase_NACHT_nucleoside_triphosphatase.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Glutathione_S-transferase__C-terminal-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are MAM_domain_MAM_domain_MAM_domain_MAM_domain.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Severe combined immunodeficiency due to DCLRE1C deficiency Lig4 syndrome. The affected domains of the variant in COSMIC are DNA_ligase__ATP-dependent__C-terminal.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
# ...
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Benign. The traits are not provided. The affected domains of the variant in COSMIC are APCDD1_domain_APCDD1_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Galactose_mutarotase.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Pleckstrin_homology_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are COMMD1_N-terminal_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Myosin_tail.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Glycosyltransferase_2-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Small-subunit_processome__Utp21.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are ENTH__domain_ENTH__domain_ENTH__domain_Epsin.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Immunoglobulin_I-set_Immunoglobulin-like_domain_Immunoglobulin_subtype.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are EF-hand_domain_EF-hand_domain_EF-hand_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are LRRC8__pannexin-like_TM_region.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Sodium/calcium_exchanger_membrane_region.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Fascin_domain_Fascin_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Immunoglobulin_V-set_domain_Immunoglobulin-like_domain_Immunoglobulin_subtype.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are RNA_polymerase_Rpb1__domain_5.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Membrane_attack_complex_component/perforin__MACPF__domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Aortic aneurysm, familial thoracic 7. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Megalencephalic leukoencephalopathy with subcortical cysts 1. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Cardiomyopathy Dilated cardiomyopathy 1G Limb-girdle muscular dystrophy, type 2J not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Intermediate_filament__rod_domain_Intermediate_filament__rod_domain_Intermediate_filament__rod_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Fibronectin_type_III_Fibronectin_type_III_Fibronectin_type_III_Fibronectin_type_III.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Tibial muscular dystrophy Myopathy, myofibrillar, 9, with early respiratory failure Dilated cardiomyopathy 1G Limb-girdle muscular dystrophy, type 2J Myopathy, early-onset, with fatal cardiomyopathy not specified. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are THUMP_domain_THUMP_domain_THUMP_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Actin.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Progressive familial heart block type IB. The affected domains of the variant in COSMIC are Ion_transport_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Phosphoinositide-specific_phospholipase_C__EF-hand-like_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are GPCR.',
#  'The clinical relevance of the variant is Benign. The traits are Curry-Hall syndrome Ellis-van Creveld syndrome not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are Early infantile epileptic encephalopathy with suppression bursts. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not specified. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are FAM91__C-terminal_domain.',
#  'The clinical relevance of the variant is Benign/Likely_benign. The traits are not specified not provided. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Keratin_type_II_head.',
#  'The clinical relevance of the variant is Uncertain_significance. The traits are not specified. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Dynein_heavy_chain__coiled_coil_stalk.',
#  'The clinical relevance of the variant is Benign. The traits are Herpes simplex encephalitis 1. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Cadherin-like_Cadherin-like.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is Conflicting_interpretations_of_pathogenicity. The traits are Macular dystrophy Cone dystrophy 3 Usher syndrome not provided. The affected domains of the variant in COSMIC are EF-hand_domain.',
#  'The clinical relevance of the variant is not annotated. No traits are known. The affected domains of the variant in COSMIC are Flotillin.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  'The clinical relevance of the variant is not annotated. No traits are known. No domains in COSMIC.',
#  ...]

# %%
set(df["dbNSFP_clinvar_clnsig"])
# Out:
# {'.',
#  'Benign',
#  'Benign/Likely_benign',
#  'Conflicting_interpretations_of_pathogenicity',
#  'Likely_benign',
#  'Likely_pathogenic',
#  'Pathogenic',
#  'Pathogenic/Likely_pathogenic',
#  'Uncertain_significance',
#  'association',
#  'drug_response',
#  'drug_response,_risk_factor',
#  'not_provided',
#  'protective'}

# %%
from transformers import TapasForQuestionAnswering, TapasTokenizer
model_name = "google/tapas-large-finetuned-wtq"
model = TapasForQuestionAnswering.from_pretrained(model_name, output_hidden_states=True)
tokenizer = TapasTokenizer.from_pretrained(model_name)

# %%
inputs = tokenizer(table=table[table.columns[:10]].head(100), queries=["What is this?"], return_tensors="pt", padding="max_length")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (3750 > 512). Running this sequence through the model will result in indexing errors.

# %%
import torch
with torch.no_grad():
    outputs = model(**inputs)

# %%
last_hidden_state = outputs.hidden_states[-1]
embeddings_numpy = last_hidden_state.cpu().numpy()

# %%
embeddings_numpy.shape
# Out:
# (1, 784, 1024)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import numpy as np


class BioGPTEmbedder(object):
    def __init__(self):
        self.tokenizer = AutoTokenizer.from_pretrained("microsoft/biogpt")
        self.model = AutoModelForCausalLM.from_pretrained("microsoft/biogpt")

    def calculate(self, text_inputs):
        X = np.zeros((len(text_inputs), 1024), dtype=np.float32)
        for i, text in enumerate(text_inputs):
            encoded_input = self.tokenizer(text, return_tensors="pt")
            with torch.no_grad():
                hidden_states = self.model.base_model(**encoded_input).last_hidden_state
            mean_encoding = torch.mean(hidden_states, dim=1)
            mean_encoding_np = mean_encoding.numpy()
            X[i, :] = mean_encoding_np
        return X

embedder = BioGPTEmbedder()

# %%
embedder.calculate(["the gene is AURKA"])
# Out:
# array([[-0.9741001 ,  0.13654037,  0.23815162, ..., -0.01901363,
#         -0.05405765,  0.06725373]], dtype=float32)

# %%
with open()
# Out:
# SAMPLE
# CHROM
# POS
# REF
# ALT
# ANN[*].GENE
# ANN[*].GENEID
# ANN[*].FEATURE
# ANN[*].FEATUREID
# ANN[*].BIOTYPE
# ANN[*].EFFECT
# ANN[*].IMPACT
# ANN[*].RANK
# ANN[*].HGVS_C
# ANN[*].HGVS_P
# ANN[*].CDNA_POS
# ANN[*].CDNA_LEN
# ANN[*].CDS_POS
# ANN[*].CDS_LEN
# ANN[*].AA_POS
# ANN[*].AA_LEN
# ANN[*].DISTANCE
# ANN[*].ALLELE
# ANN[*].ERRORS
# ID
# AF
# AC
# NS
# AN
# EAS_AF
# EUR_AF
# AFR_AF
# AMR_AF
# SAS_AF
# dbNSFP_gnomAD_exomes_AC,dbNSFP_gnomAD_exomes_AN
# dbNSFP_gnomAD_exomes_AF
# dbNSFP_gnomAD_exomes_POPMAX_AC
# dbNSFP_gnomAD_exomes_POPMAX_AN
# dbNSFP_gnomAD_exomes_POPMAX_AF
# dbNSFP_gnomAD_exomes_AFR_AC
# dbNSFP_gnomAD_exomes_AFR_AN
# dbNSFP_gnomAD_exomes_AFR_AF
# dbNSFP_gnomAD_exomes_NFE_AC
# dbNSFP_gnomAD_exomes_NFE_AN
# dbNSFP_gnomAD_exomes_NFE_AF
# dbNSFP_gnomAD_exomes_AMR_AC
# dbNSFP_gnomAD_exomes_AMR_AN
# dbNSFP_gnomAD_exomes_AMR_AF
# dbNSFP_gnomAD_exomes_ASJ_AC
# dbNSFP_gnomAD_exomes_ASJ_AN
# dbNSFP_gnomAD_exomes_ASJ_AF
# dbNSFP_gnomAD_exomes_EAS_AC
# dbNSFP_gnomAD_exomes_EAS_AN
# dbNSFP_gnomAD_exomes_EAS_AF
# dbNSFP_gnomAD_exomes_FIN_AC
# dbNSFP_gnomAD_exomes_FIN_AN
# dbNSFP_gnomAD_exomes_FIN_AF
# dbNSFP_gnomAD_exomes_SAS_AC
# dbNSFP_gnomAD_exomes_SAS_AN
# dbNSFP_gnomAD_exomes_SAS_AF
# dbNSFP_gnomAD_genomes_AC
# dbNSFP_gnomAD_genomes_AN
# dbNSFP_gnomAD_genomes_AF
# dbNSFP_gnomAD_genomes_POPMAX_AC
# dbNSFP_gnomAD_genomes_POPMAX_AN
# dbNSFP_gnomAD_genomes_POPMAX_AF
# dbNSFP_gnomAD_genomes_AFR_AC
# dbNSFP_gnomAD_genomes_AFR_AN
# dbNSFP_gnomAD_genomes_AFR_AF
# dbNSFP_gnomAD_genomes_NFE_AN
# dbNSFP_gnomAD_genomes_NFE_AC
# dbNSFP_gnomAD_genomes_NFE_AF
# dbNSFP_gnomAD_genomes_AMI_AC
# dbNSFP_gnomAD_genomes_AMI_AN
# dbNSFP_gnomAD_genomes_AMI_AF
# dbNSFP_gnomAD_genomes_AMR_AC
# dbNSFP_gnomAD_genomes_AMR_AN
# dbNSFP_gnomAD_genomes_AMR_AF
# dbNSFP_gnomAD_genomes_ASJ_AC
# dbNSFP_gnomAD_genomes_ASJ_AN
# dbNSFP_gnomAD_genomes_ASJ_AF
# dbNSFP_gnomAD_genomes_EAS_AC
# dbNSFP_gnomAD_genomes_EAS_AN
# dbNSFP_gnomAD_genomes_EAS_AF
# dbNSFP_gnomAD_genomes_FIN_AN
# dbNSFP_gnomAD_genomes_FIN_AF
# dbNSFP_gnomAD_genomes_MID_AC
# dbNSFP_gnomAD_genomes_MID_AN
# dbNSFP_gnomAD_genomes_MID_AF
# dbNSFP_gnomAD_genomes_SAS_AC
# dbNSFP_gnomAD_genomes_SAS_AN
# dbNSFP_gnomAD_genomes_SAS_AF
# dbNSFP_1000Gp3_AC
# dbNSFP_1000Gp3_AF
# dbNSFP_1000Gp3_AFR_AC
# dbNSFP_1000Gp3_AFR_AF
# dbNSFP_1000Gp3_AMR_AC
# dbNSFP_1000Gp3_AMR_AF
# dbNSFP_1000Gp3_EAS_AC
# dbNSFP_1000Gp3_EAS_AF
# dbNSFP_1000Gp3_EUR_AC
# dbNSFP_1000Gp3_EUR_AF
# dbNSFP_1000Gp3_SAS_AC
# dbNSFP_1000Gp3_SAS_AF
# dbNSFP_ESP6500_AA_AC
# dbNSFP_ESP6500_AA_AF
# dbNSFP_ESP6500_EA_AC
# dbNSFP_ESP6500_EA_AF
# dbNSFP_ExAC_AC
# dbNSFP_ExAC_AF
# dbNSFP_ExAC_Adj_AC
# dbNSFP_ExAC_Adj_AF
# dbNSFP_ExAC_AFR_AC
# dbNSFP_ExAC_AFR_AF
# dbNSFP_ExAC_AMR_AC
# dbNSFP_ExAC_AMR_AF
# dbNSFP_ExAC_EAS_AC
# dbNSFP_ExAC_EAS_AF
# dbNSFP_ExAC_FIN_AC
# dbNSFP_ExAC_FIN_AF
# dbNSFP_ExAC_NFE_AC
# dbNSFP_ExAC_NFE_AF
# dbNSFP_ExAC_SAS_AC
# dbNSFP_ExAC_SAS_AF
# dbNSFP_CADD_phred
# dbNSFP_Polyphen2_HDIV_score
# dbNSFP_Polyphen2_HDIV_pred
# dbNSFP_SIFT_score
# dbNSFP_SIFT_pred
# dbNSFP_MutationAssessor_score
# dbNSFP_MutationAssessor_pred
# dbNSFP_MutationTaster_score
# dbNSFP_MutationTaster_pred
# dbNSFP_PROVEAN_pred
# dbNSFP_VEST4_score
# dbNSFP_clinvar_id
# dbNSFP_clinvar_clnsig
# dbNSFP_clinvar_trait
# dbNSFP_clinvar_review
# dbNSFP_clinvar_MedGen_id
# dbNSFP_clinvar_OMIM_id
# dbNSFP_clinvar_Orphanet_id
# COSV_ID
# dbNSFP_Interpro_domain
