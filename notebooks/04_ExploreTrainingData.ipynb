# %%
import pandas as pd
import os
import numpy as np

df = pd.read_csv("../data/ml_datasets_matrix/df_only_pk_only_adme_genes.csv", index_col=0)

# %%
# Out:
#                              O00337  O15244  O15245  O15438  O15439  O15440  \
# AAKJLRGGTJKAMG-UHFFFAOYSA-N       0       0       0       0       0       0
# AAOVKJBEBIDNHE-UHFFFAOYSA-N       0       0       0       0       0       0
# ADEBPBSSDYVVLD-UHFFFAOYSA-N       0       0       0       0       0       0
# ADIMAYPTOBDMTL-UHFFFAOYSA-N       0       0       0       0       0       0
# AEUTYOVWOVBAKS-UHFFFAOYSA-N       0       0       0       0       0       0
# ...                             ...     ...     ...     ...     ...     ...
# ZFXYFBGIUFBOJW-UHFFFAOYSA-N       0       0       0       0       0       0
# ZKIAIYBUSXZPLP-UHFFFAOYSA-N       0       0       0       0       0       0
# ZNRGQMMCGHDTEI-UHFFFAOYSA-N       0       0       0       0       0       0
# ZSCDBOWYZJWBIY-UHFFFAOYSA-N       0       0       0       0       0       0
# ZUXABONWMNSFBN-UHFFFAOYSA-N       0       0       0       0       0       0
#
# ...

# %%
np.sum(np.array(df))
# Out:
# 15952
